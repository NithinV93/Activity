# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('diabetes_model.csv')

# %%
pd.DataFrame(data)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %% [markdown]
# # Countplot-Outcome

# %%
warnings.filterwarnings('ignore')

# %%
sns.countplot(data['Outcome'])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [markdown]
# # Boxplot-Effect of age on outcome

# %%
sns.boxplot(x='Outcome',y='Age',data=data).set_title('Effect of age on outcome')
# Out:
# Text(0.5, 1.0, 'Effect of age on outcome')

# %% [markdown]
# # Chances of diabetes, if common in family using pedigree function

# %%
sns.swarmplot(x='Outcome', y='DiabetesPedigreeFunction',data=data)
plt.title('Chances of diabetes, if common in family using pedigree function ')
# Out:
# Text(0.5, 1.0, 'Chances of diabetes, if common in family using pedigree function ')

# %% [markdown]
# # Insulin glucose Relation

# %%
plt.scatter(data['Insulin'],data['Glucose'])
plt.title('Insulin-Glucose')
plt.xlabel('Insulin')
plt.ylabel('Glucose')
# Out:
# Text(0, 0.5, 'Glucose')

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>
