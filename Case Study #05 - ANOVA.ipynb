# %%
#Importing libraies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stat

# %%
#Importing dataset

data=pd.read_csv('Sales_data_zone_wise.csv')
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
#Checking shape

data.shape
# Out:
# (29, 5)

# %%
#Checking data types

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
#Checking if  null values are present or not

data.isnull().sum()
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %%
#Statistical analysis on dataset

data.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %%
#Plotting correlation using heatmap

cor=data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), vmin=0, vmax=1, linewidth=1, annot=True, cmap='PiYG')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q1.The mean sales generated by each zone.

# %%
#Listing column names

data.columns
# Out:
# Index(['Month', 'Zone - A', 'Zone - B', 'Zone - C', 'Zone - D'], dtype='object')

# %%
#Finding mean sales

zmean=data[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].mean()

# %%
zmean.round(3)
# Out:
# Zone - A    1540493.138
# Zone - B    1755559.586
# Zone - C    1772871.034
# Zone - D    1842926.759
# dtype: float64

# %%
data1=data.drop('Month',axis=1)

# %%
data1
# Out:
#     Zone - A  Zone - B  Zone - C  Zone - D
# 0    1483525   1748451   1523308   2267260
# 1    1238428   1707421   2212113   1994341
# 2    1860771   2091194   1282374   1241600
# 3    1871571   1759617   2290580   2252681
# 4    1244922   1606010   1818334   1326062
# 5    1534390   1573128   1751825   2292044
# 6    1820196   1992031   1786826   1688055
# 7    1625696   1665534   2161754   2363315
# 8    1652644   1873402   1755290   1422059
# 9    1852450   1913059   1754314   1608387
# 10   2004480   1740365   1317869   1970069
# 11   1537539   1875658   1237722   1460165
# 12   1254939   1588473   1348629   1733383
# 13   1821799   1844081   1617376   1872259
# 14   1128185   1804613   1767047   1234311
# 15   1491534   1542053   1882159   1590913
# 16   1182110   1552388   2234469   2180416
# 17   1770324   1699213   1249821   2364132
# 18   1181635   1959268   2009168   1821882
# 19   1305972   1559670   2107949   2151008
# 20   1570152   2013615   1540016   2265814
# ...

# %%
#Plotting bar plot for mean sales generated in each zone

znames=data1.columns
plt.figure(figsize=(10,8))
sns.barplot(x=znames,y=zmean)
plt.title('Mean sales generated by each zone', fontsize=14)
plt.xlabel('Differnt Zones')
plt.ylabel('Mean Sales')
plt.grid()
plt.show()

# %% [markdown]
# From the Zone D ihas highest sales and Zone A is lowest. Zone-D>Zone-C>Zone-B>Zone-A.

# %% [markdown]
# # Q2.Total sales generated by all the zones for each month.

# %%
data["Total Sales"] = data.sum(axis=1)

# %%
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  Total Sales
# 0    Month - 1   1483525   1748451   1523308   2267260      7022544
# 1    Month - 2   1238428   1707421   2212113   1994341      7152303
# 2    Month - 3   1860771   2091194   1282374   1241600      6475939
# 3    Month - 4   1871571   1759617   2290580   2252681      8174449
# 4    Month - 5   1244922   1606010   1818334   1326062      5995328
# 5    Month - 6   1534390   1573128   1751825   2292044      7151387
# 6    Month - 7   1820196   1992031   1786826   1688055      7287108
# 7    Month - 8   1625696   1665534   2161754   2363315      7816299
# 8    Month - 9   1652644   1873402   1755290   1422059      6703395
# 9   Month - 10   1852450   1913059   1754314   1608387      7128210
# 10  Month - 11   2004480   1740365   1317869   1970069      7032783
# 11  Month - 12   1537539   1875658   1237722   1460165      6111084
# 12  Month - 13   1254939   1588473   1348629   1733383      5925424
# ...

# %%
plt.figure(figsize=(20,8))
sns.barplot(x=data["Month"],y=data["Total Sales"])
plt.title('Total Sales by Month', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %% [markdown]
# From above barplot it is evident that highest total sales is in Month 4 and lowest was in Month 13.

# %% [markdown]
# # Q3.Check whether all the zones generate the same amount of sales.

# %%
#Checking whether all the zones generate the same amount of sales or not by checking the equality of means.
#One-way ANOVA is usedfor checking the equality of means

# %% [markdown]
# H0 : ALL THE ZONES GENERATE SAME AMOUNT OF SALES.
#
# H1 : ATLEAST ONE OF THE ZONE GENERATE DIFFERENT AMOUNT OF SALES.

# %%
#Finding f and p values
f_value,p_value=stat.f_oneway(data['Zone - A'],data['Zone - B'],data['Zone - C'],data['Zone - D'])

# %%
print(f_value,p_value)
# Out:
# 5.672056106843581 0.0011827601694503335

# %%
#Checking if p value is less than or greater than the alpha value .05

# %%
if p_value<0.05:
    print(" Since P value",p_value,"is less than .05(alpha value), we can reject the null hypothesis")
else:
    print(" Since P value",p_value,"is greater than .05(alpha value), we cant reject the null hypothesis")
# Out:
#  Since P value 0.0011827601694503335 is less than .05(alpha value), we can reject the null hypothesis

# %% [markdown]
#  P Value=0.0011827601694503335 which is less than the alpha value .05 so we reject the Null Hypothesis and we can conclude that atleast one of the zone generate different amount of sales compared to the others.
